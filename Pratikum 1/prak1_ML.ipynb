# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'luas': [6, 8, 10, 9, 18],
        'harga': [7, 9, 13, 11, 18 ]}

df = pd.DataFrame(data)
df
# Out:
#    luas  harga
# 0     6      7
# 1     8      9
# 2    10     13
# 3     9     11
# 4    18     18

# %%
import numpy as np
